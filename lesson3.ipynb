# %%
import cv2

# %%
img1 = cv2.imread('img.jpg')
img2 = cv2.imread('img0.png')

r_img1 = cv2.resize(img1, (720, 720))
r_img2 = cv2.resize(img2, (720, 720))

img_sum = cv2.addWeighted(r_img1, 1, r_img2, 0.2, 0)

cv2.imshow('image', img_sum)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# QObject::moveToThread: Current thread (0x55fb826c33f0) is not the object's thread (0x55fb82e61410).
# Cannot move to target thread (0x55fb826c33f0)
#
# ...
